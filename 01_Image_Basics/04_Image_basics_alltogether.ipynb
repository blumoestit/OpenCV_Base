# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Blooms.jpg')

# %%
plt.imshow(img);

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb);

# %%
flip_img = img_rgb

# %%
flip_img = cv2.flip(flip_img, 0)
plt.imshow(flip_img);

# %%
img_rgb.shape
# Out:
# (2989, 2988, 3)

# %%
cv2.rectangle(img_rgb, pt1=(0, 500), pt2=(500, 2900),
             color=(0,0,0), thickness=-1)
plt.imshow(img_rgb);

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
vertices = np.array([[250,700],[425,400],[600,700]],np.int32)
pts = vertices.reshape((-1,1,2))
cv2.polylines(img_rgb,[pts],isClosed=True,color=(0,0,255),thickness=20)
plt.imshow(img_rgb);

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
vertices = np.array([[250,700],[425,400],[600,700]],np.int32)
pts = vertices.reshape((-1,1,2))

cv2.fillPoly(img_rgb,[pts],color=(0,0,255))
plt.imshow(img_rgb);

# %%
import cv2
import numpy as np
# Create a function based on a CV2 Event (Left button click)
def draw_circle(event,x,y,flags,param):
    if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),100,(0,0,255),10)

# Open Image
img = cv2.imread("Bloom.jpg")
# This names the window so we can reference it 
cv2.namedWindow(winname='bloom')
# Connects the mouse button to our callback function
cv2.setMouseCallback('bloom',draw_circle)

while True: #Runs forever until we break with Esc key on keyboard
    # Shows the image window
    cv2.imshow('bloom',img)
    # EXPLANATION FOR THIS LINE OF CODE:
    # https://stackoverflow.com/questions/35372700/whats-0xff-for-in-cv2-waitkey1/39201163
    if cv2.waitKey(20) & 0xFF == 27:
        break
# Once script is done, its usually good practice to call this line
# It closes all windows (just in case you have multiple windows called)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-19-9b40b8fbaf13> in <module>
#      15 while True: #Runs forever until we break with Esc key on keyboard
#      16     # Shows the image window
# ---> 17     cv2.imshow('bloom',img)
#      18     # EXPLANATION FOR THIS LINE OF CODE:
#      19     # https://stackoverflow.com/questions/35372700/whats-0xff-for-in-cv2-waitkey1/39201163
#
# error: OpenCV(4.5.2) /private/var/folders/24/8k48jl6d249_n_qfxwsl6xvm0000gn/T/pip-req-build-7jsmxh8y/opencv/modules/highgui/src/window.cpp:404: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'
